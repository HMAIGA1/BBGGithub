# %% [markdown]
# # <center><img src="https://s3.dev.rrdc.bcs.bloomberg.com/global-data-training/data-analysis-with-python/images/course_logo.png" alt="drawing" width="100"/><br>Data Analysis with Python Classroom Sessions</center>
#
# -----
#
# ### Welcome to the BQuant project for our Data Analysis with Python course!
# This BQuant project includes supporting notebooks for what's covered in three classroom sessions for *Data Analysis with Python*. It also includes an additional fun analysis for a dataset about LEGOs using `pandas` and `matplotlib`!
#
# Please select below to explore one of our Python Notebooks:
#
# 1. [Classroom Session 1 - Variables / Lists / Functions](classroom-1.ipynb)
# 2. [Classroom Session 2 - NumPy](classroom-2-numpy.ipynb)
# 3. [Classroom Session 3 - Pandas](classroom-3-pandas.ipynb)
#
# * [Additional NumPy exercises](numpy-practice.ipynb)
# * [LEGO Analysis Example Project](lego-analysis.ipynb)

# %% [markdown]
# ---
# _Sheil Naik & Ian Barbour_
